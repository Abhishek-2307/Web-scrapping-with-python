# %% [markdown]
# ### Importing modules

# %%
import warnings
warnings.simplefilter(action='ignore',category=FutureWarning)

# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
scrapped_csv = "scraped_cars.csv"

# %% [markdown]
# ## Load CSV and Review

# %%
df_raw = pd.read_csv(scrapped_csv)
df = df_raw.copy() # keep a defensive copy of the original data
df.head()
# Out:
#                         name  cylinders  weight  year territory  acceleration  \
# 0  Chevrolet Chevelle Malibu          8    3504  1970       USA          12.0
# 1          Buick Skylark 320          8    3693  1970       USA          11.5
# 2         Plymouth Satellite          8    3436  1970       USA          11.0
# 3              Amc Rebel Sst          8    3433  1970       USA          12.0
# 4                Ford Torino          8    3449  1970       USA          10.5
#
#     mpg     hp  displacement
# 0  18.0  130.0         307.0
# 1  15.0  165.0         350.0
# 2  18.0  150.0         318.0
# 3  16.0  150.0         304.0
# 4  17.0  140.0         302.0

# %%
df.shape
# Out:
# (406, 9)

# %%
df.describe()
# Out:
#         cylinders       weight         year  acceleration         mpg  \
# count  406.000000   406.000000   406.000000    406.000000  398.000000
# mean     5.475369  2979.413793  1975.921182     15.519704   23.514573
# std      1.712160   847.004328     3.748737      2.803359    7.815984
# min      3.000000  1613.000000  1970.000000      8.000000    9.000000
# 25%      4.000000  2226.500000  1973.000000     13.700000   17.500000
# 50%      4.000000  2822.500000  1976.000000     15.500000   23.000000
# 75%      8.000000  3618.250000  1979.000000     17.175000   29.000000
# max      8.000000  5140.000000  1982.000000     24.800000   46.600000
#
#                hp  displacement
# count  400.000000    406.000000
# mean   105.082500    194.779557
# std     38.768779    104.922458
# min     46.000000     68.000000
# 25%     75.750000    105.000000
# 50%     95.000000    151.000000
# 75%    130.000000    302.000000
# max    230.000000    455.000000

# %% [markdown]
# ## Data Review Strategy

# %%
df.territory.value_counts()
# Out:
# USA       254
# Japan      79
# Europe     73
# Name: territory, dtype: int64

# %%
df.cylinders.value_counts()
# Out:
# 4    207
# 8    108
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
df.cylinders.value_counts().sort_index()
# Out:
# 3      4
# 4    207
# 5      3
# 6     84
# 8    108
# Name: cylinders, dtype: int64

# %%
ax = sns.countplot(data=df, y='cylinders')
ax.set_title("Counts for Each Cylinder Type");

# %%
ax = sns.countplot(data=df, x='year')
ax.set_title('Counts of  Cars per Year');
plt.xticks(rotation=45);

# %%
df.isnull().sum()
# Out:
# name            0
# cylinders       0
# weight          0
# year            0
# territory       0
# acceleration    0
# mpg             8
# hp              6
# displacement    0
# dtype: int64

# %%
df.mpg.isnull()[5:15]
# Out:
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# Name: mpg, dtype: bool

# %%
df[df.mpg.isnull()]
# Out:
#                                  name  cylinders  weight  year territory  \
# 10               Citroen Ds-21 Pallas          4    3090  1970    Europe
# 11   Chevrolet Chevelle Concours (Sw)          8    4142  1970       USA
# 12                   Ford Torino (Sw)          8    4034  1970       USA
# 13            Plymouth Satellite (Sw)          8    4166  1970       USA
# 14                 Amc Rebel Sst (Sw)          8    3850  1970       USA
# 17              Ford Mustang Boss 302          8    3353  1970       USA
# 39        Volkswagen Super Beetle 117          4    1978  1971    Europe
# 367                         Saab 900S          4    2800  1981    Europe
#
#      acceleration  mpg     hp  displacement
# 10           17.5  NaN  115.0         133.0
# 11           11.5  NaN  165.0         350.0
# 12           11.0  NaN  153.0         351.0
# 13           10.5  NaN  175.0         383.0
# 14           11.0  NaN  175.0         360.0
# 17            8.0  NaN  140.0         302.0
# 39           20.0  NaN   48.0          97.0
# 367          15.4  NaN  110.0         121.0

# %%
df[df.hp.isnull()]
# Out:
#                      name  cylinders  weight  year territory  acceleration  \
# 38             Ford Pinto          4    2046  1971       USA          19.0
# 133         Ford Maverick          6    2875  1974       USA          17.0
# 337  Renault Lecar Deluxe          4    1835  1980    Europe          17.3
# 343    Ford Mustang Cobra          4    2905  1980       USA          14.3
# 361           Renault 18I          4    2320  1981    Europe          15.8
# 382        Amc Concord Dl          4    3035  1982       USA          20.5
#
#       mpg  hp  displacement
# 38   25.0 NaN          98.0
# 133  21.0 NaN         200.0
# 337  40.9 NaN          85.0
# 343  23.6 NaN         140.0
# 361  34.5 NaN         100.0
# 382  23.0 NaN         151.0

# %%
def highlight_max(s):
    '''Highlight the maximu in s Series yellow'''
    is_max = s == s.max()
    return ['Background-color: yellow' if v else '' for v in is_max]
df.pivot_table(index=['year'], aggfunc='count').style.apply(highlight_max, axis=1)
# Out:
# <style  type="text/css" >
#     #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row0_col0 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row0_col1 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row0_col2 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row0_col3 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row0_col5 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row0_col6 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row0_col7 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row1_col0 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row1_col1 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row1_col2 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row1_col5 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row1_col6 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row1_col7 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row2_col0 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row2_col1 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row2_col2 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row2_col3 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row2_col4 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row2_col5 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row2_col6 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row2_col7 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row3_col0 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row3_col1 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row3_col2 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row3_col3 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row3_col4 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row3_col5 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row3_col6 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row3_col7 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row4_col0 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row4_col1 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row4_col2 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row4_col4 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row4_col5 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row4_col6 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row4_col7 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row5_col0 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row5_col1 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row5_col2 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row5_col3 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row5_col4 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row5_col5 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row5_col6 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row5_col7 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row6_col0 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row6_col1 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row6_col2 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row6_col3 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row6_col4 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row6_col5 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row6_col6 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row6_col7 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row7_col0 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row7_col1 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row7_col2 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row7_col3 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row7_col4 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row7_col5 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row7_col6 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row7_col7 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row8_col0 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row8_col1 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row8_col2 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row8_col3 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row8_col4 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row8_col5 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row8_col6 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row8_col7 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row9_col0 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row9_col1 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row9_col2 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row9_col3 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row9_col4 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row9_col5 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row9_col6 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row9_col7 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f66row10_col0 {
#             Background-color:  yellow;
#         }    #T_5127eee6_874b_11e9_91ee_90cdb66c3f6

# %%
print(f"Before we drop Nan rows we have {df.shape} rows")
df = df.dropna()
print(f"After we drop Nan rows we have {df.shape} rows")
# Out:
# Before we drop Nan rows we have (406, 9) rows
# After we drop Nan rows we have (392, 9) rows

# %%
df.cylinders.value_counts().sort_index()
# Out:
# 3      4
# 4    199
# 5      3
# 6     83
# 8    103
# Name: cylinders, dtype: int64

# %%
df = df.query("cylinders != 3 and cylinders != 5").copy()
df.cylinders.value_counts().sort_index()
# Out:
# 4    199
# 6     83
# 8    103
# Name: cylinders, dtype: int64

# %% [markdown]
# ### what Distribution Does MPG Have?

# %%
print(f"Examples of MPG values: {list(df.mpg.sample(10).sort_values())}")
ax = df.mpg.hist()
ax.set_ylabel('Frequency')
ax.set_xlabel('Binned MPG')
ax.set_title('Histogram of Continuous weight (lbs) values');
# Out:
# Examples of MPG values: [11.0, 14.0, 17.0, 20.2, 21.1, 21.5, 21.6, 24.0, 26.0, 43.1]

# %%
ax = df.weight.hist()
ax.set_ylabel('Frequency')
ax.set_xlabel('Binned weight')
ax.set_title('Histogram of Continuous weight (lbs) values');

# %% [markdown]
# ###  Reviewing Our Goal

# %%
df.pivot_table(index=['year'],aggfunc='mean')
# Out:
#       acceleration  cylinders  displacement          hp        mpg  \
# year
# 1970     12.948276   6.758621    281.413793  147.827586  17.689655
# 1971     15.000000   5.629630    213.888889  107.037037  21.111111
# 1972     15.185185   5.925926    223.870370  121.037037  18.703704
# 1973     14.333333   6.461538    261.666667  131.512821  17.076923
# 1974     16.173077   5.230769    170.653846   94.230769  22.769231
# 1975     16.050000   5.600000    205.533333  101.066667  20.266667
# 1976     15.941176   5.647059    197.794118  101.117647  21.573529
# 1977     15.507407   5.555556    195.518519  104.888889  23.444444
# 1978     15.802857   5.371429    179.142857   99.600000  24.168571
# 1979     15.660714   5.857143    207.535714  102.071429  25.082143
# 1980     17.084000   4.160000    117.720000   77.000000  34.104000
# 1981     16.325000   4.642857    136.571429   81.035714  30.185714
# 1982     16.510000   4.200000    128.133333   81.466667  32.000000
#
#            weight
# year
# 1970  3372.793103
# 1971  3030.592593
# 1972  3271.333333
# 1973  3452.230769
# 1974  2878.038462
# 1975  3176.800000
# 1976  3078.735294
# 1977  3007.629630
# 1978  2862.714286
# 1979  3038.392857
# 1980  2422.120000
# 1981  2530.178571
# 1982  2434.166667

# %% [markdown]
# ### What Correlates with MPG?

# %%
df.corr()['mpg'].sort_values()
# Out:
# weight         -0.842681
# displacement   -0.817887
# cylinders      -0.794872
# hp             -0.780259
# acceleration    0.419337
# year            0.579778
# mpg             1.000000
# Name: mpg, dtype: float64

# %% [markdown]
# ### Exploring MPG vs Weight

# %%
ax = df.plot(kind='scatter',x='weight',y='mpg')
ax.set_title('Scatterplot of MPG vs. Weight (lbs)');

# %%
ax = df.plot(kind='scatter', x='weight', y='mpg',alpha=0.5)
ax.set_title('Scatterplot of MPG vs. Weight (lbs)');

# %%
jg = sns.jointplot(data=df, x='weight',y='mpg');
jg.fig.suptitle('Somewhat Non-linear Relationship between HP and Weight');

# %%
jg=sns.jointplot(data=df, x='weight', y='mpg',kind='hexbin')
jg.fig.suptitle('Hexbin of Counts for MPG vs. Weight');

# %%
jg = sns.jointplot(data=df, x='weight',y='mpg').plot_joint(sns.kdeplot, zorder=0, n_levels=5)
jg.fig.suptitle('Density Estimate for MPG vs. Weight');

# %% [markdown]
# ### Exploring HP vs Weights

# %%
ax = df.plot(kind='scatter',x='hp',y='weight')
ax.set_title('Reasonably Linear Retaionship between HP and weight');

# %%
jg = sns.jointplot(data=df, x='hp', y='weight', kind='reg')
jg.fig.suptitle('Reasonably Linear Relationship between HP and weight');

# %%
df.query("hp > 200 and weight < 3500") # Fully equipped luxury entrant
# Out:
#                        name  cylinders  weight  year territory  acceleration  \
# 19  Buick Estate Wagon (Sw)          8    3086  1970       USA          10.0
#
#      mpg     hp  displacement
# 19  14.0  225.0         455.0

# %% [markdown]
# ### Cylinders and Displacement

# %%
sorted_cylinders_label = df.cylinders.value_counts().sort_index().index
sorted_cylinders_label
# Out:
# Int64Index([4, 6, 8], dtype='int64')

# %%
ax = df.plot(kind='scatter',x='cylinders',y='displacement')
ax.set_title("Scatterplot of Cylinders vs. Displacement");

# %%
ax = sns.stripplot(data=df, x='cylinders', y='displacement', order=sorted_cylinders_label)
ax.set_title("Stripplot of Cylinders vs. Displacement");

# %%
ax = sns.boxplot(data=df, x='cylinders',y='weight', order=sorted_cylinders_label)
ax.set_title("Boxplot of Cylinders vs weight");

# %%
ax = sns.boxplot(data=df, x='cylinders', y='displacement', order=sorted_cylinders_label, notch=True)
ax.set_title("Notched Boxplot of Cylinders vs. weight");

# %% [markdown]
# ## Looking at MPG over Time

# %%
ax = df.plot(kind='scatter', x='year',y='mpg');
ax.set_title('Scatterplot of MPG by Year');

# %%
ax = sns.stripplot(data=df, x='year',y='mpg')
ax.set_title('Stripeplot of MPG by year');
plt.xticks(rotation=45);

# %%
ax = sns.boxplot(data=df, x='year',y='mpg')
ax.set_title("Boxplot of MPG by year");
plt.xticks(rotation=45);

# %%
df.query('year=="1978" and mpg> 40')
# Out:
#                                 name  cylinders  weight  year territory  \
# 251  Volkswagen Rabbit Custom Diesel          4    1985  1978    Europe
#
#      acceleration   mpg    hp  displacement
# 251          21.5  43.1  48.0          90.0

# %%
ax = df.plot(kind='scatter', x='year', y='mpg')
ax.set_title('Stripplot of MPG by year');

# %%
ax = sns.boxplot(data=df, x='year', y='weight')
ax.set_title('Boxplot of weight by Year');
plt.xticks(rotation=45);

# %% [markdown]
# ## Text Analysis

# %%
df.head()
# Out:
#                         name  cylinders  weight  year territory  acceleration  \
# 0  Chevrolet Chevelle Malibu          8    3504  1970       USA          12.0
# 1          Buick Skylark 320          8    3693  1970       USA          11.5
# 2         Plymouth Satellite          8    3436  1970       USA          11.0
# 3              Amc Rebel Sst          8    3433  1970       USA          12.0
# 4                Ford Torino          8    3449  1970       USA          10.5
#
#     mpg     hp  displacement
# 0  18.0  130.0         307.0
# 1  15.0  165.0         350.0
# 2  18.0  150.0         318.0
# 3  16.0  150.0         304.0
# 4  17.0  140.0         302.0

# %%
ser_car_makes = df.name.str.lower().str.split(n=1,expand=True)[0]
ser_car_makes.value_counts()[:10]
# Out:
# ford          48
# chevrolet     43
# plymouth      31
# dodge         28
# amc           27
# toyota        25
# datsun        23
# buick         17
# pontiac       16
# volkswagen    15
# Name: 0, dtype: int64

# %%
ser_car_makes.value_counts()[-10:]
# Out:
# cadillac         2
# mercedes-benz    2
# hi               1
# capri            1
# chevroelt        1
# maxda            1
# toyouta          1
# triumph          1
# vokswagen        1
# nissan           1
# Name: 0, dtype: int64

# %%
df['car_makes'] = ser_car_makes
ser_cars_by_territory = df[['territory','car_makes']].pivot_table(index=['territory','car_makes'],aggfunc='size')

# %%
df_cars_by_territory = pd.DataFrame(ser_cars_by_territory) # anonymous series
df_cars_by_territory.columns =['size'] #rename anonymous coumn 0 to a named columns

# %%
df_cars_by_territory = df_cars_by_territory.sort_values(by=['size'], ascending=False)
df_cars_by_territory
# Out:
#                          size
# territory car_makes
# USA       ford             48
#           chevrolet        43
#           plymouth         31
#           dodge            28
#           amc              27
# Japan     toyota           25
#           datsun           23
# USA       buick            17
#           pontiac          16
# Europe    volkswagen       15
# Japan     honda            13
# USA       mercury          11
#           oldsmobile       10
# Europe    peugeot           8
#           fiat              8
# Japan     mazda             7
# Europe    volvo             6
#           vw                6
# USA       chrysler          6
# Europe    audi              5
#           saab              4
#           opel              4
# Japan     subaru            4
# USA       chevy             3
# Europe    renault           3
#           bmw               2
# USA       cadillac          2
# Europe    mercedes-benz     2
# Japan     toyouta           1
#           nissan            1
# USA       capri             1
#           chevroelt         1
# Japan     maxda             1
# Europe    vokswagen         1
#           triumph           1
# USA       hi                1

# %%
mask = df_cars_by_territory.apply(lambda x: x['size']> 10, axis=1)
df_cars_by_territory[mask]
# Out:
#                       size
# territory car_makes
# USA       ford          48
#           chevrolet     43
#           plymouth      31
#           dodge         28
#           amc           27
# Japan     toyota        25
#           datsun        23
# USA       buick         17
#           pontiac       16
# Europe    volkswagen    15
# Japan     honda         13
# USA       mercury       11

# %% [markdown]
# ## Report
#
# This report answer the following questions:
#
# . Is there a relationship between weight and MPG -yes with more weight we generally see lower MPG.
#
# . Is there a relationship between Cylinders and Dispalcement -yes with more Cylinders we see a higher Displacement .
#
# . Is there a relatioship between MPG and Years - yes generally as we move from 1970 to 1982 we see steady improvements in MPG

# %%
print(f"df_raw had shape {df_raw.shape}, after dropping NaN entries we \
reduced from {df_raw.shape[0]} to {df.shape[0]} rows.")

assert ((df.mpg >= 7) & (df.mpg <= 47)).all(), "Why do we see wider range of MPG values now?"
assert ((df.year >= 1970) & (df.year <= 1982)).all(), "why doe we see a wider range of years now?"
# Out:
# df_raw had shape (406, 9), after dropping NaN entries we reduced from 406 to 385 rows.

# %% [markdown]
# #### As weight increases we see a decrease in MPG, this relationship is slightly non-linear with faster decrease in MPG associated with low-to-mid weight.

# %%
jg = sns.jointplot(data=df, x='weight', y='mpg').plot_joint(sns.kdeplot, zorder=0, n_levels=5)
jg.fig.suptitle('Density Estimate for MPG vs. Weight');

# %% [markdown]
# #### Acceleration gets worse as Horsepower decreases

# %%
jg = sns.jointplot(data=df, x='acceleration',y='hp',kind='reg')
jg.fig.suptitle('Regression plot for Acceleration vs. Horsepower');

# %% [markdown]
# #### An engine's cubic inches of displacement is strongly related to the court of Cylinders

# %%
ax = sns.boxplot(data=df, x='cylinders', y='displacement', order=sorted_cylinders_label,notch=True)
sns.stripplot(data=df, x='cylinders', y='displacement', order=sorted_cylinders_label, alpha=0.5, ax=ax)
ax.set_title("More Cylinders Generally Have\nHigher Cubic Inches of Displacement");

# %% [markdown]
# #### Heavier vehicles tend to have more Horsepower, the heaviest vehicles have the highest count of cylinders.

# %%
fig, ax = plt.subplots(figsize=(6,6))
df.plot(kind='scatter',x='weight',y='hp')
ax.set_title('Scatterplot of HP vs. Weight\nColoured by Cylinder Count');

# %% [markdown]
# #### Vehicle brands are strongly associated with Territory

# %%
cm = sns.light_palette("green", as_cmap=True)
mask = df_cars_by_territory.apply(lambda x: x['size'] > 10, axis=1)
df_cars_by_territory[mask].style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_533e7df4_8826_11e9_b7d7_90cdb66c3f66row0_col0 {
#             background-color:  #008000;
#         }    #T_533e7df4_8826_11e9_b7d7_90cdb66c3f66row1_col0 {
#             background-color:  #1f911f;
#         }    #T_533e7df4_8826_11e9_b7d7_90cdb66c3f66row2_col0 {
#             background-color:  #69ba69;
#         }    #T_533e7df4_8826_11e9_b7d7_90cdb66c3f66row3_col0 {
#             background-color:  #7cc57c;
#         }    #T_533e7df4_8826_11e9_b7d7_90cdb66c3f66row4_col0 {
#             background-color:  #82c882;
#         }    #T_533e7df4_8826_11e9_b7d7_90cdb66c3f66row5_col0 {
#             background-color:  #8fcf8f;
#         }    #T_533e7df4_8826_11e9_b7d7_90cdb66c3f66row6_col0 {
#             background-color:  #9bd69b;
#         }    #T_533e7df4_8826_11e9_b7d7_90cdb66c3f66row7_col0 {
#             background-color:  #c1ebc1;
#         }    #T_533e7df4_8826_11e9_b7d7_90cdb66c3f66row8_col0 {
#             background-color:  #c7eec7;
#         }    #T_533e7df4_8826_11e9_b7d7_90cdb66c3f66row9_col0 {
#             background-color:  #cdf2cd;
#         }    #T_533e7df4_8826_11e9_b7d7_90cdb66c3f66row10_col0 {
#             background-color:  #daf9da;
#         }    #T_533e7df4_8826_11e9_b7d7_90cdb66c3f66row11_col0 {
#             background-color:  #e5ffe5;
#         }</style>
# <table id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >size</th>
#     </tr>    <tr>
#         <th class="index_name level0" >territory</th>
#         <th class="index_name level1" >car_makes</th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66" class="row_heading level0 row0" rowspan=5>USA</th>
#         <th id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66" class="row_heading level1 row0" >ford</th>
#         <td id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66row0_col0" class="data row0 col0" >48</td>
#     </tr>    <tr>
#         <th id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66" class="row_heading level1 row1" >chevrolet</th>
#         <td id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66row1_col0" class="data row1 col0" >43</td>
#     </tr>    <tr>
#         <th id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66" class="row_heading level1 row2" >plymouth</th>
#         <td id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66row2_col0" class="data row2 col0" >31</td>
#     </tr>    <tr>
#         <th id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66" class="row_heading level1 row3" >dodge</th>
#         <td id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66row3_col0" class="data row3 col0" >28</td>
#     </tr>    <tr>
#         <th id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66" class="row_heading level1 row4" >amc</th>
#         <td id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66row4_col0" class="data row4 col0" >27</td>
#     </tr>    <tr>
#         <th id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66" class="row_heading level0 row5" rowspan=2>Japan</th>
#         <th id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66" class="row_heading level1 row5" >toyota</th>
#         <td id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66row5_col0" class="data row5 col0" >25</td>
#     </tr>    <tr>
#         <th id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66" class="row_heading level1 row6" >datsun</th>
#         <td id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66row6_col0" class="data row6 col0" >23</td>
#     </tr>    <tr>
#         <th id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66" class="row_heading level0 row7" rowspan=2>USA</th>
#         <th id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66" class="row_heading level1 row7" >buick</th>
#         <td id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66row7_col0" class="data row7 col0" >17</td>
#     </tr>    <tr>
#         <th id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66" class="row_heading level1 row8" >pontiac</th>
#         <td id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66row8_col0" class="data row8 col0" >16</td>
#     </tr>    <tr>
#         <th id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66" class="row_heading level0 row9" >Europe</th>
#         <th id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66" class="row_heading level1 row9" >volkswagen</th>
#         <td id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66row9_col0" class="data row9 col0" >15</td>
#     </tr>    <tr>
#         <th id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66" class="row_heading level0 row10" >Japan</th>
#         <th id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66" class="row_heading level1 row10" >honda</th>
#         <td id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66row10_col0" class="data row10 col0" >13</td>
#     </tr>    <tr>
#         <th id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66" class="row_heading level0 row11" >USA</th>
#         <th id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66" class="row_heading level1 row11" >mercury</th>
#         <td id="T_533e7df4_8826_11e9_b7d7_90cdb66c3f66row11_col0" class="data row11 col0" >11</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# #### Vehicles from USA consistently have worse MPG thean corresponding vehilces from Japan or Europe in this sample. Vehicles in each territory become more efficent over the Years.

# %%
fg = sns.lmplot(data=df, x='year',y='mpg', hue='territory')
fg.fig.suptitle('MPG over Year by Territory');
